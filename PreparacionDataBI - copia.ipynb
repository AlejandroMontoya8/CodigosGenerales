# %%
import pandas as pd
import numpy as np
import os
import datetime as dt
from datetime import date
from pymongo import MongoClient

# %%
Hoy =date.today()
Hoy = Hoy - dt.timedelta(days=29)

# %%
Hoy
# Out:
# datetime.date(2022, 12, 1)

# %%
fecha_actual_menos1
# Out:
# datetime.date(2022, 12, 1)

# %%
fecha_actual = Hoy 
fecha_actual_menos1 = fecha_actual - dt.timedelta(days = 0)
fecha_actual_menos2 = fecha_actual_menos1 - dt.timedelta(days = 31)
mes_actual = fecha_actual.month
mes_actual_menos1 = fecha_actual_menos1.month
mes_actual_menos2 = fecha_actual_menos2.month



if mes_actual<10:
    mes_actual= str("0")+str(mes_actual)
else: mes_actual = str(mes_actual)
    
if mes_actual_menos1<10:
    mes_actual_menos1 = str("0") + str(mes_actual_menos1)
else:  mes_actual_menos1 = str(mes_actual_menos1)

if mes_actual_menos2<10:
    mes_actual_menos2 = str("0") + str(mes_actual_menos2)
else:  mes_actual_menos2 = str(mes_actual_menos2)
    

    
dict_mes={"01":"Ene","02":"Feb","03":"Mar","04":"Abr","05":"May","06":"Jun","07":"Jul","08":"Ago","09":"Sep","10":"Oct","11":"Nov","12":"Dic"}
dict_mes_largo ={"Ene":"Enero","Feb":"Febrero","Mar":"Marzo","Abr":"Abril","May":"Mayo","Jun":"Junio","Jul":"Julio","Ago":"Agosto","Sep":"Septiembre","Oct":"Octubre","Nov":"Noviembre","Dic":"Diciembre"}
mes_actual=dict_mes[mes_actual]
mes_actual_menos1 = dict_mes[mes_actual_menos1]
mes_actual_menos2 = dict_mes[mes_actual_menos2]

mes_actual_copia = dict_mes_largo[mes_actual]
mes_actual_menos1_copia = dict_mes_largo[mes_actual_menos1]
mes_actual_menos2_copia = dict_mes_largo[mes_actual_menos2]

anio = fecha_actual.year
anio_corto = fecha_actual.year - 2000

if mes_actual == "Ene":
    mes_actual_menos1 = mes_actual_menos1 + " " +  str(anio_corto - 1)
    mes_actual_menos1_copia = mes_actual_menos1_copia +" " +  str(anio -1)
    mes_actual_menos2 = mes_actual_menos2 + " " + str(anio_corto - 1)
    mes_actual_menos2_copia = mes_actual_menos2_copia +" " + str(anio -1)
    
else:
    mes_actual_menos1 = mes_actual_menos1 + " " +  str(anio_corto)
    mes_actual_menos1_copia = mes_actual_menos1_copia +" " +  str(anio)
    mes_actual_menos2 = mes_actual_menos2 + " " + str(anio_corto)
    mes_actual_menos2_copia = mes_actual_menos2_copia + " " + str(anio)
    
    
mes_actual = mes_actual + " " + str(anio_corto)
mes_actual_copia = mes_actual_copia + " " + str(anio)

# %%
resumen_total = pd.DataFrame(columns=["ORDER_HEADER_KEY","ENTRY_TYPE","ORDER_NO","DOCUMENT_TYPE","ORDER_DATE","ORDER_TYPE","LEVEL_OF_SERVICE","CUSTOMER_PHONE_NO","EXTN_RUN_RUT_NIT","ORIGINAL_TOTAL_AMOUNT","PAYMENT_TYPE","STATUS_NAME","EXTN_ORG_REQ_SHIP_DATE","STATUS_DATE","EXTN_ET_FULFILMENT","SHIPNODE_KEY"])
for the_file in os.listdir(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Querys result\1) RESUMEN"):
    if mes_actual_copia in the_file or mes_actual_menos1_copia in the_file:
        archivo_subida = os.path.join(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Querys result\1) RESUMEN",the_file)             ###Importación del archivo de resumen
        resumen_parcial=pd.read_csv(archivo_subida,sep=",")
        columnas_resumen= ["RN","ORDER_HEADER_KEY","ENTRY_TYPE","ORDER_NO","DOCUMENT_TYPE","ORDER_DATE","ORDER_TYPE","ENTRY_TYPE2","LEVEL_OF_SERVICE","CUSTOMER_PHONE_NO","EXTN_RUN_RUT_NIT","ORIGINAL_TOTAL_AMOUNT","ENTERPRISE_KEY","PAYMENT_TYPE","STATUS_NAME","EXTN_ORG_REQ_SHIP_DATE","STATUS_DATE","EXTN_ET_FULFILMENT","SHIPNODE_KEY"]  
        
        iteracion = len(resumen_parcial.columns) - len(columnas_resumen)
        for i in range(iteracion):
            columnas_resumen.append("BLANCO")
            
        resumen_parcial.columns=columnas_resumen
        resumen_parcial=resumen_parcial.drop(0,axis=0)
        print(the_file)
        resumen_parcial=resumen_parcial[["ORDER_HEADER_KEY","ENTRY_TYPE","ORDER_NO","DOCUMENT_TYPE","ORDER_DATE","ORDER_TYPE","LEVEL_OF_SERVICE","CUSTOMER_PHONE_NO","EXTN_RUN_RUT_NIT","ORIGINAL_TOTAL_AMOUNT","PAYMENT_TYPE","STATUS_NAME","EXTN_ORG_REQ_SHIP_DATE","STATUS_DATE","EXTN_ET_FULFILMENT","SHIPNODE_KEY"]]
        resumen_total = pd.concat([resumen_total,resumen_parcial],axis=0)
        
resumen_total = resumen_total.drop_duplicates(subset = ["ORDER_NO","STATUS_NAME"])
# Out:
# Diciembre 2022(1).csv
# Diciembre 2022(2).csv
# Diciembre 2022(3).csv
# Diciembre 2022(4).csv
# Diciembre 2022(5).csv
# Diciembre 2022(6).csv
# Diciembre 2022(7).csv
# Diciembre 2022(8).csv
# Diciembre 2022(9).csv

# %%
tiempos_total = pd.DataFrame(columns=["ORDER_NO","ORDER_HEADER_KEY","STATUS","STATUS_DATE","CREATEUSERID","MODIFYUSERID","SHIPMENT_KEY","SCAC","SHIPNODE_KEY","ASSIGNED_TO_USER_ID"])
for the_file in os.listdir(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Querys result\4) TIEMPOS"):
    if mes_actual_copia in the_file or mes_actual_menos1_copia in the_file:
        archivo_subida = os.path.join(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Querys result\4) TIEMPOS",the_file) ###Importación de la base de tiempos
        tiempos_parcial=pd.read_csv(archivo_subida,sep=",")
        columnas_tiempos = ["RN","ORDER_NO","ORDER_HEADER_KEY","STATUS","STATUS_DATE","CREATEUSERID","MODIFYUSERID","SHIPMENT_KEY","SCAC","SHIPNODE_KEY","ASSIGNED_TO_USER_ID"]
        iteracion = len(tiempos_parcial.columns) - len(columnas_tiempos)
        for i in range(iteracion):
            columnas_tiempos.append("BLANCO")
    
        tiempos_parcial.columns=columnas_tiempos
        tiempos_parcial=tiempos_parcial.drop(0,axis=0)
        print(the_file)
        tiempos_parcial = tiempos_parcial[["ORDER_NO","ORDER_HEADER_KEY","STATUS","STATUS_DATE","CREATEUSERID","MODIFYUSERID","SHIPMENT_KEY","SCAC","SHIPNODE_KEY","ASSIGNED_TO_USER_ID"]]
        tiempos_total = pd.concat([tiempos_total,tiempos_parcial],axis=0)
        
tiempos_total = tiempos_total.drop_duplicates(subset=["ORDER_NO","STATUS","STATUS_DATE"])

tiempos_total["STATUS_DATE"] = pd.to_datetime(tiempos_total["STATUS_DATE"],format="%Y-%m-%d %H:%M:%S")
status_date_inicial = tiempos_total["STATUS_DATE"]
STATUS_DATE_COL =[]

for fecha in status_date_inicial:                        ###Se convierte el status date a fecha hora colombia
    resta = fecha - dt.timedelta(hours=5)
    STATUS_DATE_COL.append(resta)
    
    
    
tiempos_total["STATUS_DATE_COL"] = STATUS_DATE_COL


packing_complete = tiempos_total[tiempos_total.STATUS.isin(['3350.1500.1000'])]
packing_complete = packing_complete[["ORDER_NO","STATUS_DATE_COL"]]
packing_complete = packing_complete.drop_duplicates(subset = ["ORDER_NO"])

read_for_bp = tiempos_total[tiempos_total.STATUS.isin(['3350.1000'])]

read_for_bp = read_for_bp.sort_values("STATUS_DATE_COL",ascending = True)
primer_read_for_bp = read_for_bp.drop_duplicates(subset = ["ORDER_NO"],keep = "first")
ult_read_for_bp = read_for_bp.drop_duplicates(subset = ["ORDER_NO"],keep = "last")
ult_read_for_bp = ult_read_for_bp[["ORDER_NO","STATUS_DATE_COL"]]
# Out:
# Diciembre 2022(1).csv
# Diciembre 2022(10).csv
# Diciembre 2022(11).csv
# Diciembre 2022(12).csv
# Diciembre 2022(13).csv
# Diciembre 2022(14).csv
# Diciembre 2022(15).csv
# Diciembre 2022(16).csv
# Diciembre 2022(17).csv
# Diciembre 2022(18).csv
# Diciembre 2022(19).csv
# Diciembre 2022(2).csv
# Diciembre 2022(20).csv
# Diciembre 2022(21).csv
# Diciembre 2022(22).csv
# Diciembre 2022(23).csv
# Diciembre 2022(24).csv
# Diciembre 2022(25).csv
# Diciembre 2022(26).csv
# Diciembre 2022(27).csv
# Diciembre 2022(28).csv
# Diciembre 2022(29).csv
# Diciembre 2022(3).csv
# Diciembre 2022(30).csv
# Diciembre 2022(31).csv
# Diciembre 2022(32).csv
# Diciembre 2022(33).csv
# Diciembre 2022(34).csv
# Diciembre 2022(35).csv
# Diciembre 2022(36).csv
# Diciembre 2022(37).csv
# Diciembre 2022(38).csv
# Diciembre 2022(39).csv
# Diciembre 2022(4).csv
# Diciembre 2022(40).csv
# Diciembre 2022(41).csv
# Diciembre 2022(42).csv
# Diciembre 2022(43).csv
# Diciembre 2022(44).csv
# Diciembre 2022(45).csv
# ...

# %%
resumen_total = pd.merge(resumen_total,primer_read_for_bp,left_on = "ORDER_NO",right_on = "ORDER_NO",how = "left")
resumen_total = resumen_total[['ORDER_HEADER_KEY_x', 'ENTRY_TYPE', 'ORDER_NO', 'DOCUMENT_TYPE',
       'ORDER_DATE', 'ORDER_TYPE', 'LEVEL_OF_SERVICE', 'CUSTOMER_PHONE_NO',
       'EXTN_RUN_RUT_NIT', 'ORIGINAL_TOTAL_AMOUNT', 'PAYMENT_TYPE',
       'STATUS_NAME', 'EXTN_ORG_REQ_SHIP_DATE', 'STATUS_DATE_x',
       'EXTN_ET_FULFILMENT', 'SHIPNODE_KEY_x', 'CREATEUSERID', 'MODIFYUSERID', 'SHIPMENT_KEY', 'SCAC',
       'ASSIGNED_TO_USER_ID', 'STATUS_DATE_COL']]

resumen_total.columns = ['ORDER_HEADER_KEY', 'ENTRY_TYPE', 'ORDER_NO', 'DOCUMENT_TYPE',
       'ORDER_DATE', 'ORDER_TYPE', 'LEVEL_OF_SERVICE', 'CUSTOMER_PHONE_NO',
       'EXTN_RUN_RUT_NIT', 'ORIGINAL_TOTAL_AMOUNT', 'PAYMENT_TYPE',
       'STATUS_NAME', 'EXTN_ORG_REQ_SHIP_DATE', 'STATUS_DATE',
       'EXTN_ET_FULFILMENT', 'SHIPNODE_KEY', 'CREATEUSERID', 'MODIFYUSERID', 'SHIPMENT_KEY', 'SCAC',
       'ASSIGNED_TO_USER_ID', '1erReadyForBackRoomPick']

resumen_total = pd.merge(resumen_total,ult_read_for_bp,left_on = ["ORDER_NO"],right_on = ["ORDER_NO"],how = "left")
resumen_total = resumen_total[['ORDER_HEADER_KEY', 'ENTRY_TYPE', 'ORDER_NO', 'DOCUMENT_TYPE',
       'ORDER_DATE', 'ORDER_TYPE', 'LEVEL_OF_SERVICE', 'CUSTOMER_PHONE_NO',
       'EXTN_RUN_RUT_NIT', 'ORIGINAL_TOTAL_AMOUNT', 'PAYMENT_TYPE',
       'STATUS_NAME', 'EXTN_ORG_REQ_SHIP_DATE', 'STATUS_DATE',
       'EXTN_ET_FULFILMENT', 'SHIPNODE_KEY', 'CREATEUSERID', 'MODIFYUSERID', 'SHIPMENT_KEY', 'SCAC',
       'ASSIGNED_TO_USER_ID', '1erReadyForBackRoomPick', 'STATUS_DATE_COL']]

resumen_total.columns = ['ORDER_HEADER_KEY', 'ENTRY_TYPE', 'ORDER_NO', 'DOCUMENT_TYPE',
       'ORDER_DATE', 'ORDER_TYPE', 'LEVEL_OF_SERVICE', 'CUSTOMER_PHONE_NO',
       'EXTN_RUN_RUT_NIT', 'ORIGINAL_TOTAL_AMOUNT', 'PAYMENT_TYPE',
       'STATUS_NAME', 'EXTN_ORG_REQ_SHIP_DATE', 'STATUS_DATE',
       'EXTN_ET_FULFILMENT', 'SHIPNODE_KEY', 'CREATEUSERID', 'MODIFYUSERID', 'SHIPMENT_KEY', 'SCAC',
       'ASSIGNED_TO_USER_ID','1erReadyForBackRoomPick', 'ultReadyForBackRoomPick']

resumen_total = pd.merge(resumen_total,packing_complete,left_on ="ORDER_NO",right_on = "ORDER_NO",how = "left")
resumen_total = resumen_total[['ORDER_HEADER_KEY', 'ENTRY_TYPE', 'ORDER_NO', 'DOCUMENT_TYPE',
       'ORDER_DATE', 'ORDER_TYPE', 'LEVEL_OF_SERVICE', 'CUSTOMER_PHONE_NO',
       'EXTN_RUN_RUT_NIT', 'ORIGINAL_TOTAL_AMOUNT', 'PAYMENT_TYPE',
       'STATUS_NAME', 'EXTN_ORG_REQ_SHIP_DATE', 'STATUS_DATE',
       'EXTN_ET_FULFILMENT', 'SHIPNODE_KEY', 'CREATEUSERID', 'MODIFYUSERID', 'SHIPMENT_KEY', 'SCAC',
       'ASSIGNED_TO_USER_ID','1erReadyForBackRoomPick', 'ultReadyForBackRoomPick','STATUS_DATE_COL']]

resumen_total.columns = ['ORDER_HEADER_KEY', 'ENTRY_TYPE', 'ORDER_NO', 'DOCUMENT_TYPE',
       'ORDER_DATE', 'ORDER_TYPE', 'LEVEL_OF_SERVICE', 'CUSTOMER_PHONE_NO',
       'EXTN_RUN_RUT_NIT', 'ORIGINAL_TOTAL_AMOUNT', 'PAYMENT_TYPE',
       'STATUS_NAME', 'EXTN_ORG_REQ_SHIP_DATE', 'STATUS_DATE',
       'EXTN_ET_FULFILMENT', 'SHIPNODE_KEY', 'CREATEUSERID', 'MODIFYUSERID', 'SHIPMENT_KEY', 'SCAC',
       'ASSIGNED_TO_USER_ID','1erReadyForBackRoomPick', 'ultReadyForBackRoomPick','PackingComplete']

# %%
saltos_total = pd.DataFrame(columns=["ORDER_NO","ORDER_HEADER_KEY","SHIPMENT_KEY","SHIPNODE_KEY","STATUS","STATUS_DATE","DELIVERY_METHOD","ORDER_TYPE","EXTN_SHORT","ASSIGNED_TO_USER_ID"])
for the_file in os.listdir(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Querys result\5) SALTOS"):
    if mes_actual_copia in the_file or mes_actual_menos1_copia in the_file:
        archivo_subida = os.path.join(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Querys result\5) SALTOS",the_file) 
        saltos_parcial=pd.read_csv(archivo_subida,sep=",")
        columnas_saltos= ["RN","ORDER_NO","ORDER_HEADER_KEY","SHIPMENT_KEY","SHIPNODE_KEY","STATUS","STATUS_DATE","DELIVERY_METHOD","ORDER_TYPE","EXTN_SHORT","ASSIGNED_TO_USER_ID"]  
        iteracion = len(saltos_parcial.columns) - len(columnas_saltos)
        for i in range(iteracion):
            columnas_saltos.append("BLANCO")
        
        saltos_parcial.columns=columnas_saltos
        saltos_parcial=saltos_parcial.drop(0,axis=0)
        print(the_file)
        saltos_parcial=saltos_parcial[["ORDER_NO","ORDER_HEADER_KEY","SHIPMENT_KEY","SHIPNODE_KEY","STATUS","STATUS_DATE","DELIVERY_METHOD","ORDER_TYPE","EXTN_SHORT","ASSIGNED_TO_USER_ID"]]
        saltos_total = pd.concat([saltos_total,saltos_parcial],axis=0)
    
saltos_total["Tipo_Salto"] = "Sin tipo"

saltos_total.loc[(saltos_total["EXTN_SHORT"] == "PCNCL") & (~saltos_total.ASSIGNED_TO_USER_ID.isnull()),"Tipo_Salto"] = "Partial Delivery"
saltos_total.loc[(saltos_total.EXTN_SHORT.isin(["CNCL","BO"])) & (~saltos_total.ASSIGNED_TO_USER_ID.isnull()),"Tipo_Salto"]="Quiebre"
saltos_total.loc[(saltos_total.EXTN_SHORT.isnull()) & (saltos_total.ASSIGNED_TO_USER_ID.isnull()) ,"Tipo_Salto"]="Tiempo"

saltos_total = saltos_total[saltos_total["Tipo_Salto"]!="Sin tipo"]
saltos_total = saltos_total.drop_duplicates()

saltos_total = saltos_total[['ORDER_NO', 'SHIPNODE_KEY',
        'STATUS_DATE','EXTN_SHORT',
       'ASSIGNED_TO_USER_ID', 'Tipo_Salto']]
cantidad_saltos = pd.pivot_table(saltos_total,index =["ORDER_NO"],values =["Tipo_Salto"],aggfunc = "count")

cantidad_saltos=cantidad_saltos.reset_index()
cantidad_saltos.columns=["ORDER_NO","Cantidad_Saltos"]
resumen_total = pd.merge(resumen_total,cantidad_saltos,left_on = "ORDER_NO",right_on = "ORDER_NO",how = "left")
# Out:
# Diciembre 2022(1).csv

# %%
fmedica_total = pd.DataFrame(columns=["ORDER_NO","ORDER_HEADER_KEY","ORDER_DATE","DOCUMENT_TYPE","ENTRY_TYPE","PRESCRIPTION_NAME","ENTERPRISE_KEY"])

for the_file in os.listdir(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Querys result\11) ORDENES FORMULA MEDICA"):
    if mes_actual_copia in the_file or mes_actual_menos1_copia in the_file:
        archivo_subida = os.path.join(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Querys result\11) ORDENES FORMULA MEDICA",the_file)
        fmedica_parcial = pd.read_csv(archivo_subida,sep=",")
        columnas_fmedica= ["RN","ORDER_NO","ORDER_HEADER_KEY","ORDER_DATE","DOCUMENT_TYPE","ENTRY_TYPE","PRESCRIPTION_NAME","ENTERPRISE_KEY"]  
        iteracion = len(fmedica_parcial.columns) - len(columnas_fmedica)
        for i in range(iteracion):
            columnas_fmedica.append("BLANCO")
        
        fmedica_parcial.columns=columnas_fmedica
        fmedica_parcial=fmedica_parcial.drop(0,axis=0)
        print(the_file)
        fmedica_parcial=fmedica_parcial[["ORDER_NO","ORDER_HEADER_KEY","ORDER_DATE","DOCUMENT_TYPE","ENTRY_TYPE","PRESCRIPTION_NAME","ENTERPRISE_KEY"]]
        fmedica_total = pd.concat([fmedica_total,fmedica_parcial],axis=0)
    
fmedica_total = fmedica_total.drop_duplicates()
fmedica_total = fmedica_total[['ORDER_NO','PRESCRIPTION_NAME']]

resumen_total = pd.merge(resumen_total,fmedica_total,left_on = "ORDER_NO",right_on ="ORDER_NO",how = "left" )
resumen_total = resumen_total[['ORDER_HEADER_KEY', 'ENTRY_TYPE', 'ORDER_NO', 'DOCUMENT_TYPE',
       'ORDER_DATE', 'ORDER_TYPE', 'LEVEL_OF_SERVICE', 'CUSTOMER_PHONE_NO',
       'EXTN_RUN_RUT_NIT', 'ORIGINAL_TOTAL_AMOUNT', 'PAYMENT_TYPE',
       'STATUS_NAME', 'EXTN_ORG_REQ_SHIP_DATE', 'STATUS_DATE',
       'EXTN_ET_FULFILMENT', 'SHIPNODE_KEY', 'CREATEUSERID', 'MODIFYUSERID',
       'SHIPMENT_KEY', 'SCAC', 'ASSIGNED_TO_USER_ID',
       '1erReadyForBackRoomPick', 'ultReadyForBackRoomPick', 'PackingComplete',
       'Cantidad_Saltos','PRESCRIPTION_NAME']]

resumen_total.columns =  ['ORDER_HEADER_KEY', 'ENTRY_TYPE', 'ORDER_NO', 'DOCUMENT_TYPE',
       'ORDER_DATE', 'ORDER_TYPE', 'LEVEL_OF_SERVICE', 'CUSTOMER_PHONE_NO',
       'EXTN_RUN_RUT_NIT', 'ORIGINAL_TOTAL_AMOUNT', 'PAYMENT_TYPE',
       'STATUS_NAME', 'EXTN_ORG_REQ_SHIP_DATE', 'STATUS_DATE',
       'EXTN_ET_FULFILMENT', 'SHIPNODE_KEY', 'CREATEUSERID', 'MODIFYUSERID',
       'SHIPMENT_KEY', 'SCAC', 'ASSIGNED_TO_USER_ID',
       '1erReadyForBackRoomPick', 'ultReadyForBackRoomPick', 'PackingComplete',
       'Cantidad_Saltos','FormulaMedica']

resumen_total = resumen_total.drop_duplicates()
# Out:
# Diciembre 2022(1).csv
# Diciembre 2022(2).csv

# %%
um_total = pd.DataFrame(columns=['numorden', 'iniciado', 'asignado', 'llego_punto', 'salio_punto', 'llego_cliente', 'finalizado', 'distancia_km', 'Finalizado Fallido', 'Tipo Fallido', 'Valor Servicio', 'Proveedor', 'Estado UM', 'Mes','Dia'])
for the_file in os.listdir(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Querys result\Última Milla"):
    if mes_actual in the_file or  mes_actual_menos1 in the_file or mes_actual_menos2  in the_file:
        archivo_subida = os.path.join(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Querys result\Última Milla",the_file)   ###Importación de los archivos de última milla
        um_parcial = pd.read_excel(archivo_subida)
        print(the_file)
        um_total = pd.concat([um_total,um_parcial],axis=0)
    
um_total["distancia_km"] = pd.to_numeric(um_total["distancia_km"],downcast = "integer")


um_total["iniciado"] = pd.to_datetime(um_total["iniciado"], format="%Y-%m-%d %H:%M:%S")
um_total["asignado"] = pd.to_datetime(um_total["asignado"], format="%Y-%m-%d %H:%M:%S")
um_total["salio_punto"] = pd.to_datetime(um_total["salio_punto"], format="%Y-%m-%d %H:%M:%S")
um_total["llego_punto"] = pd.to_datetime(um_total["llego_punto"], format="%Y-%m-%d %H:%M:%S")
um_total["llego_cliente"] = pd.to_datetime(um_total["llego_cliente"], format="%Y-%m-%d %H:%M:%S")
um_total["finalizado"] = pd.to_datetime(um_total["finalizado"], format="%Y-%m-%d %H:%M:%S")


orden_proveedor = um_total["numorden"]
nueva_orden = []
for orden in orden_proveedor:
    orden = str(orden)
    if "_" in orden:
        orden = orden[0:orden.find("_")]
        orden = orden.replace(" ","")
        nueva_orden.append(orden)
    else: 
        orden = orden
        nueva_orden.append(orden)
um_total["numorden2"] = nueva_orden

um_total = um_total[(~um_total.llego_cliente.isnull() )& (~um_total.iniciado.isnull())]

resumen_total = pd.merge(resumen_total,um_total,left_on = "ORDER_NO",right_on="numorden2",how = "left")

resumen_total = resumen_total.drop_duplicates(subset = ["ORDER_NO","llego_cliente"])
# Out:
# 202210 - Reporte Servicios Oct 22.xlsx
# 202212 - Reporte Servicios Dic 22.xlsx

# %%
mostrador_oms_total = pd.DataFrame(columns=["CREATEUSERID","ORDER_NO"])

for the_file in os.listdir(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Querys result\Data OMS-Mostrador"):
    if mes_actual_copia in the_file or mes_actual_menos1_copia in the_file:
        archivo_subida = os.path.join(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Querys result\Data OMS-Mostrador",the_file)
        mostrador_oms_parcial = pd.read_csv(archivo_subida,sep=",")
        columnas_mostrador_oms= ["RN","ORDER_HEADER_KEY","CREATEUSERID","ENTRY_TYPE","ORDER_NO","DOCUMENT_TYPE","ORDER_DATE","ORDER_TYPE","ENTRY_TYPE","LEVEL_OF_SERVICE","CUSTOMER_PHONE_NO","EXTN_RUN_RUT_NIT","ORIGINAL_TOTAL_AMOUNT","ENTERPRISE_KEY","PAYMENT_TYPE","STATUS_NAME","EXTN_ORG_REQ_SHIP_DATE","STATUS_DATE","EXTN_ET_FULFILMENT","SHIPNODE_KEY"]  
        iteracion = len(mostrador_oms_parcial.columns) - len(columnas_mostrador_oms)
        for i in range(iteracion):
            columnas_mostrador_oms.append("BLANCO")
        
        mostrador_oms_parcial.columns=columnas_mostrador_oms
        mostrador_oms_parcial=mostrador_oms_parcial.drop(0,axis=0)
        print(the_file)
        mostrador_oms_parcial=mostrador_oms_parcial[["CREATEUSERID","ORDER_NO"]]
        mostrador_oms_total = pd.concat([mostrador_oms_total,mostrador_oms_parcial],axis=0)
        
mostrador_oms_total= mostrador_oms_total.drop_duplicates()
        
resumen_total=pd.merge(resumen_total,mostrador_oms_total,left_on="ORDER_NO",right_on = "ORDER_NO",how = "left")
resumen_total.columns = ['ORDER_HEADER_KEY', 'ENTRY_TYPE', 'ORDER_NO', 'DOCUMENT_TYPE',
       'ORDER_DATE', 'ORDER_TYPE', 'LEVEL_OF_SERVICE', 'CUSTOMER_PHONE_NO',
       'EXTN_RUN_RUT_NIT', 'ORIGINAL_TOTAL_AMOUNT', 'PAYMENT_TYPE',
       'STATUS_NAME', 'EXTN_ORG_REQ_SHIP_DATE', 'STATUS_DATE',
       'EXTN_ET_FULFILMENT', 'SHIPNODE_KEY', 'CREATEUSERID_x', 'MODIFYUSERID',
       'SHIPMENT_KEY', 'SCAC', 'ASSIGNED_TO_USER_ID',
       '1erReadyForBackRoomPick', 'ultReadyForBackRoomPick', 'PackingComplete',
       'Cantidad_Saltos', 'FormulaMedica', 'numorden', 'iniciado', 'asignado',
       'llego_punto', 'salio_punto', 'llego_cliente', 'finalizado',
       'distancia_km', 'Finalizado Fallido', 'Tipo Fallido', 'Valor Servicio',
       'Proveedor', 'Estado UM', 'Mes', 'Dia', 'numorden2','MostradorOMS']


fechas_correccion = ["1erReadyForBackRoomPick","ultReadyForBackRoomPick","PackingComplete",
                     "iniciado","asignado","llego_punto","salio_punto","llego_cliente","finalizado"]

for elemento in fechas_correccion:
    date_inicial = resumen_total[elemento]
    date_nueva = []
    for elemento2 in date_inicial:
        date_nueva.append(str(elemento2))
    
    resumen_total[elemento] = date_nueva


base_cancelados_call = resumen_total[(resumen_total["STATUS_NAME"]=="Cancelled") & (resumen_total.ORDER_NO.str.contains("COCC"))]
base_cancelados_ecomm = resumen_total[(resumen_total["STATUS_NAME"]=="Cancelled") & (resumen_total.ORDER_NO.str.contains("CO1"))]

cancelados_call = pd.read_excel(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Call center\Libros Cancelados\Libro cancelados - Call center.xlsx",sheet_name = 'Libro de Cancelados "Otros"')
cancelados_ecomm = pd.read_excel(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Call center\Libros Cancelados\Libro cancelados - E-commerce.xlsx",sheet_name = 'Libro de Cancelados "Otros"')
cancelados_call = cancelados_call[['ORDER_NO','TIPOLOGIA','Macrotipologia', 'RESPONSABLE']]
cancelados_ecomm = cancelados_ecomm[['ORDER_NO','TIPOLOGIA','Macrotipologia','RESPONSABLE']]
cancelados_call = cancelados_call.drop_duplicates()
cancelados_ecomm = cancelados_ecomm.drop_duplicates()
base_cancelados_call = pd.merge(base_cancelados_call,cancelados_call,left_on = "ORDER_NO",right_on = "ORDER_NO",how = "left")
base_cancelados_ecomm = pd.merge(base_cancelados_ecomm,cancelados_ecomm,left_on ="ORDER_NO",right_on="ORDER_NO",how = "left")
base_cancelados_total = pd.concat([base_cancelados_call,base_cancelados_ecomm],axis = 0)
base_cancelados_total = base_cancelados_total.drop_duplicates()


base_devoluciones_call = resumen_total[(resumen_total.STATUS_NAME.isin(["Return Received","Return Created","Delivery Rejected"])) & (resumen_total.ORDER_NO.str.contains("COCC"))]
base_devoluciones_ecomm = resumen_total[(resumen_total.STATUS_NAME.isin(["Return Received","Return Created","Delivery Rejected"])) & (resumen_total.ORDER_NO.str.contains("CO1"))]

devoluciones_call = pd.read_excel(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Call center\Libro Devoluciones\Libro Devoluciones - Call center 2022.xlsx",sheet_name = 'Libro de Devoluciones')
devoluciones_ecomm = pd.read_excel(r"C:\Users\luis.montoya\OneDrive - Grupo Socofar\Dashboard OMS\Call center\Libro Devoluciones\Libro Devoluciones - E-commerce.xlsx",sheet_name = 'Libro de Devoluciones')
devoluciones_call = devoluciones_call[['SALES_ORDER_NO','TIPOLOGIA','Macrotipologia', 'RESPONSABLE']]
devoluciones_ecomm = devoluciones_ecomm[['SALES_ORDER_NO','TIPOLOGIA','Macrotipologia','RESPONSABLE']]
devoluciones_call = devoluciones_call.drop_duplicates()
devoluciones_ecomm = devoluciones_ecomm.drop_duplicates()
base_devoluciones_call = pd.merge(base_devoluciones_call,devoluciones_call,left_on = "ORDER_NO",right_on = "SALES_ORDER_NO",how = "left")
base_devoluciones_ecomm = pd.merge(base_devoluciones_ecomm,devoluciones_ecomm,left_on ="ORDER_NO",right_on="SALES_ORDER_NO",how = "left")
base_devoluciones_total = pd.concat([base_devoluciones_call,base_devoluciones_ecomm],axis = 0)
base_devoluciones_total = base_devoluciones_total.drop_duplicates()
# Out:
# C:\Users\luis.montoya\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\Users\luis.montoya\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\Users\luis.montoya\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\Users\luis.montoya\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
local_host= 'mongodb://localhost'
client = MongoClient(local_host)

db = client['BD_OMS']

collection = db['Resumen_Total']
resumen_total_import = resumen_total.to_dict(orient="records")
collection.insert_many(resumen_total_import)

collection = db['Saltos_total']
saltos_total_import = saltos_total.to_dict(orient="records")
collection.insert_many(saltos_total_import)

collection = db['base_cancelados_total']
base_cancelados_total_import = base_cancelados_total.to_dict(orient="records")
collection.insert_many(base_cancelados_total_import)

collection = db['base_devoluciones_total']
base_devoluciones_total_import = base_devoluciones_total.to_dict(orient="records")
collection.insert_many(base_devoluciones_total_import)

# %%
resumen_total.to_excel(r"C:\Users\nataly.garcia\Desktop\ResumenTotalprueba.xlsx")
saltos_total.to_excel(r"C:\Users\nataly.garcia\Desktop\saltosTotalprueba.xlsx")
base_cancelados_total.to_excel(r"C:\Users\nataly.garcia\Desktop\canceladosTotalprueba.xlsx")
base_devoluciones_total.to_excel(r"C:\Users\nataly.garcia\Desktop\devolucionesTotalprueba.xlsx")
